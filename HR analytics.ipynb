# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
hr=pd.read_csv('datasets/HR-Employee-Attrition.csv')
hr
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
hr.loc[hr['Attrition']=='Yes','Attrition']=1
hr.loc[hr['Attrition']=='No','Attrition']=0
hr
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41         1      Travel_Rarely       1102                   Sales
# 1      49         0  Travel_Frequently        279  Research & Development
# 2      37         1      Travel_Rarely       1373  Research & Development
# 3      33         0  Travel_Frequently       1392  Research & Development
# 4      27         0      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36         0  Travel_Frequently        884  Research & Development
# 1466   39         0      Travel_Rarely        613  Research & Development
# 1467   27         0      Travel_Rarely        155  Research & Development
# 1468   49         0  Travel_Frequently       1023                   Sales
# 1469   34         0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
hr['Attrition']=hr['Attrition'].astype(float)

# %%
hr['Attrition']
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 1465    0.0
# 1466    0.0
# 1467    0.0
# 1468    0.0
# 1469    0.0
# Name: Attrition, Length: 1470, dtype: float64

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
hr.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
hr.duplicated().sum()
# Out:
# 0

# %%
hr.MaritalStatus.unique()
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %%
hr
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41         1      Travel_Rarely       1102                   Sales
# 1      49         0  Travel_Frequently        279  Research & Development
# 2      37         1      Travel_Rarely       1373  Research & Development
# 3      33         0  Travel_Frequently       1392  Research & Development
# 4      27         0      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36         0  Travel_Frequently        884  Research & Development
# 1466   39         0      Travel_Rarely        613  Research & Development
# 1467   27         0      Travel_Rarely        155  Research & Development
# 1468   49         0  Travel_Frequently       1023                   Sales
# 1469   34         0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # Age Groups

# %%
hr.Age.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# most number of employees are 35 years of age followed by 34 years age group.
# there are very few employees which are 57 years old

# %% [markdown]
# # Business Travel
# Employees who have

# %%
hr.BusinessTravel.value_counts().plot(kind='pie',autopct='%0.1f%%',title='Business Travel')
# Out:
# <AxesSubplot:title={'center':'Business Travel'}, ylabel='BusinessTravel'>

# %% [markdown]
# Most no of employees travels Rarely with count of 71%

# %% [markdown]
# # Department

# %%
hr.Department.value_counts().plot(kind='pie',autopct='%0.1f%%',title='Department of employees')
# Out:
# <AxesSubplot:title={'center':'Department of employees'}, ylabel='Department'>

# %% [markdown]
# Most of the employees are from Research & Development Department
# while there are very less no of employees from Human Resources DEpartment

# %% [markdown]
# # Gender

# %%
hr.Gender.value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
hr.Gender.value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Gender'>

# %% [markdown]
# The ratio of male and women employees are 60:40 .
#
# The total count of male and female employees are 882 and 588

# %% [markdown]
# # Education Field of Employees

# %%
hr.EducationField.value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='EducationField'>

# %% [markdown]
# most number of employees are from Life Science (41.2%) and Medical Field (31.6%)

# %% [markdown]
# # Marital Status of employees

# %%
hr.MaritalStatus.value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
hr.MaritalStatus.value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='MaritalStatus'>

# %% [markdown]
# Married    - 673 (45.8%)
#
# Single     - 470 (32.0%)
#
# Divorced   - 327 (22.2%)

# %% [markdown]
# # Job Role

# %%
hr.JobRole.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Most of the employees work as 'Sales Executive' while the count of employees work as 'Human Resources' Role are very less

# %% [markdown]
# # Working Years

# %%
hr.TotalWorkingYears.value_counts()
# Out:
# 10    202
# 6     125
# 8     103
# 9      96
# 5      88
# 7      81
# 1      81
# 4      63
# 12     48
# 3      42
# 15     40
# 16     37
# 11     36
# 13     36
# 21     34
# 17     33
# 2      31
# 14     31
# 20     30
# 18     27
# 19     22
# 23     22
# 22     21
# 24     18
# 25     14
# 28     14
# 26     14
# 0      11
# 29     10
# 31      9
# 32      9
# 30      7
# 33      7
# 27      7
# 36      6
# 34      5
# 37      4
# 35      3
# 40      2
# 38      1
# Name: TotalWorkingYears, dtype: int64

# %%
hr.TotalWorkingYears.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are 200+ Employees who worked for 10 years.
#
# There are Total of 11 freshers who are working for less than a year.
#
# only one employee  worked for 38 years.
#
# 2 employees worked for 40 years, They are the oldest employees in the company

# %% [markdown]
# # Number of companies worked

# %%
hr.NumCompaniesWorked.value_counts()
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64

# %%
hr.NumCompaniesWorked.value_counts().plot(kind='bar')
plt.xlabel('Number of Companies Changed')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# There are more than 500 employees who has changed only 1 company
#
# there are nearly 200 employees who never changed there company
#
# nearly 50 employees have changed 9 companies

# %%
hr.groupby('NumCompaniesWorked')['Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked,Gender'>

# %% [markdown]
# # Attrition

# %%
hr.Attrition.value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
hr.Attrition.value_counts().plot(kind='pie',autopct='%0.1f%%',title='Attrition')
# Out:
# <AxesSubplot:title={'center':'Attrition'}, ylabel='Attrition'>

# %% [markdown]
# 61.1% employees may leave the company voluntarily or involuntarily. Or, they may move from one department to another

# %%
hr.loc[hr['Attrition']=='Yes','Gender'].value_counts().plot(kind='pie',autopct='%0.1f%%',title='Attrition rate of male and female employees ')
# Out:
# <AxesSubplot:title={'center':'Attrition rate of male and female employees '}, ylabel='Gender'>

# %% [markdown]
# The attrition rate of Male employees are higher than Female employees.
#
# male-63.3%
# Female-36.7%

# %% [markdown]
# # Distance from home

# %%
hr.DistanceFromHome.value_counts()
# Out:
# 2     211
# 1     208
# 10     86
# 9      85
# 3      84
# 7      84
# 8      80
# 5      65
# 4      64
# 6      59
# 16     32
# 11     29
# 24     28
# 23     27
# 29     27
# 15     26
# 18     26
# 26     25
# 25     25
# 20     25
# 28     23
# 19     22
# 14     21
# 12     20
# 17     20
# 22     19
# 13     19
# 21     18
# 27     12
# Name: DistanceFromHome, dtype: int64

# %%
hr.DistanceFromHome.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are 27employee with max distance from home of 29 km.
#
# More than 400 employees lives around 1 and 2 km distance

# %% [markdown]
# # Attrition and Age relation

# %%
hr.loc[hr['Attrition']==1,'Age'].value_counts()
# Out:
# 31    18
# 29    18
# 28    14
# 33    12
# 26    12
# 32    11
# 35    10
# 34     9
# 30     9
# 24     7
# 21     6
# 44     6
# 37     6
# 19     6
# 41     6
# 25     6
# 20     6
# 39     6
# 36     6
# 40     5
# 50     5
# 22     5
# 58     5
# 23     4
# 46     4
# 18     4
# 56     3
# 55     3
# 27     3
# 52     3
# 47     3
# 48     2
# 45     2
# 42     2
# 38     2
# 51     2
# 49     2
# 43     2
# 53     2
# Name: Age, dtype: int64

# %%
hr.loc[hr['Attrition']==1,'Age'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Employees with age group of 31 and 29 have 18 no of employees respectively who will follow Attrition

# %% [markdown]
# # Marital Status and Attrition

# %%
hr1=hr.groupby('MaritalStatus')['Attrition'].value_counts()
hr1.to_csv('Marital_Attrition.csv')
hr1=pd.read_csv('Marital_Attrition.csv')
# hr1=pd.pivot_table(hr1,values=None,index='Attrition',columns='MaritalStatus',fill_value=0, aggfunc=np.sum)
hr1=pd.pivot_table(hr1,values=None,index='MaritalStatus',columns='Attrition',fill_value=0, aggfunc=np.sum)
hr1.plot(kind='bar')
# px.bar(hr1)
# Out:
# <AxesSubplot:xlabel='MaritalStatus'>

# %%
hr1.plot()
# Out:
# <AxesSubplot:xlabel='MaritalStatus'>

# %%
px.bar(hr.RelationshipSatisfaction.value_counts())
# Out:
# <div>                            <div id="29bdc20b-6b97-47e9-b619-b2259b7a3d54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29bdc20b-6b97-47e9-b619-b2259b7a3d54")) {                    Plotly.newPlot(                        "29bdc20b-6b97-47e9-b619-b2259b7a3d54",                        [{"alignmentgroup":"True","hovertemplate":"variable=RelationshipSatisfaction<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"RelationshipSatisfaction","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"RelationshipSatisfaction","offsetgroup":"RelationshipSatisfaction","orientation":"v","showlegend":true,"textposition":"auto","x":[3,4,2,1],"xaxis":"x","y":[459,432,303,276],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"
# ...

# %%
hr.Education
# Out:
# 0       2
# 1       1
# 2       2
# 3       4
# 4       1
#        ..
# 1465    2
# 1466    1
# 1467    3
# 1468    3
# 1469    3
# Name: Education, Length: 1470, dtype: int64

# %%
hr.DailyRate
# Out:
# 0       1102
# 1        279
# 2       1373
# 3       1392
# 4        591
#         ...
# 1465     884
# 1466     613
# 1467     155
# 1468    1023
# 1469     628
# Name: DailyRate, Length: 1470, dtype: int64

# %%
hr0=hr[['Age', 'Attrition',
       'DistanceFromHome', 'EnvironmentSatisfaction','Department',
        'JobSatisfaction', 'MonthlyIncome',
        'PercentSalaryHike',
       'RelationshipSatisfaction',
       'TotalWorkingYears', 
       'YearsAtCompany']]
hr0
# Out:
#       Age Attrition  DistanceFromHome  EnvironmentSatisfaction  \
# 0      41         1                 1                        2
# 1      49         0                 8                        3
# 2      37         1                 2                        4
# 3      33         0                 3                        4
# 4      27         0                 2                        1
# ...   ...       ...               ...                      ...
# 1465   36         0                23                        3
# 1466   39         0                 6                        4
# 1467   27         0                 4                        2
# 1468   49         0                 2                        4
# 1469   34         0                 8                        2
#
#                   Department  JobSatisfaction  MonthlyIncome  \
# 0                      Sales                4           5993
# 1     Research & Development                2           5130
# ...

# %%
hr0=hr0[hr0['Department']=='Research & Development'].corr()

# %%
sns.heatmap(hr0)
# Out:
# <AxesSubplot:>

# %%
hr.groupby('Department')['Attrition'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Attrition'>

# %%
hr.loc[hr['Department']=='Research & Development'].groupby('Department')['Attrition'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Attrition'>

# %%
hr.loc[hr['Department']=='Human Resources'].groupby('Department')['Attrition'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Attrition'>

# %%
hr.loc[hr['Department']=='Sales'].groupby('Department')['Attrition'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Attrition'>

# %%
hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
h11=hr[['Age', 'Attrition', 'BusinessTravel', 
       'DistanceFromHome',  'EnvironmentSatisfaction', 'Gender', 
    'JobInvolvement',  'JobSatisfaction',
        'MonthlyIncome', 
       'PercentSalaryHike', 'PerformanceRating',
        'TotalWorkingYears',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]
h11
# Out:
#       Age  Attrition     BusinessTravel  DistanceFromHome  \
# 0      41        1.0      Travel_Rarely                 1
# 1      49        0.0  Travel_Frequently                 8
# 2      37        1.0      Travel_Rarely                 2
# 3      33        0.0  Travel_Frequently                 3
# 4      27        0.0      Travel_Rarely                 2
# ...   ...        ...                ...               ...
# 1465   36        0.0  Travel_Frequently                23
# 1466   39        0.0      Travel_Rarely                 6
# 1467   27        0.0      Travel_Rarely                 4
# 1468   49        0.0  Travel_Frequently                 2
# 1469   34        0.0      Travel_Rarely                 8
#
#       EnvironmentSatisfaction  Gender  JobInvolvement  JobSatisfaction  \
# 0                           2  Female               3                4
# 1                           3    Male               2                2
# ...

# %%
hr11.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  \
# Age                      1.000000  -0.159205         -0.001686
# Attrition               -0.159205   1.000000          0.077924
# DistanceFromHome        -0.001686   0.077924          1.000000
# EnvironmentSatisfaction  0.010146  -0.103369         -0.016075
# JobInvolvement           0.029820  -0.130016          0.008783
# JobSatisfaction         -0.004892  -0.103481         -0.003669
# MonthlyIncome            0.497855  -0.159840         -0.017014
# PercentSalaryHike        0.003634  -0.013478          0.040235
# TotalWorkingYears        0.680381  -0.171063          0.004628
# YearsAtCompany           0.311309  -0.134392          0.009508
# YearsInCurrentRole       0.212901  -0.160545          0.018845
# YearsSinceLastPromotion  0.216513  -0.033019          0.010029
# YearsWithCurrManager     0.202089  -0.156199          0.014406
#
#                          EnvironmentSatisfaction  JobInvolvement  \
# ...

# %%
sns.heatmap(hr11.corr(),cmap='Accent')
# Out:
# <AxesSubplot:>

# %%
hr11.groupby('Attrition')['PercentSalaryHike','DistanceFromHome'].mean().plot(kind='bar')
# Out:
# C:\Users\Mayur\AppData\Local\Temp\ipykernel_16368\3995720443.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <AxesSubplot:xlabel='Attrition'>

# %%
hr11.groupby('Attrition')['PercentSalaryHike','DistanceFromHome'].mean()
# Out:
# C:\Users\Mayur\AppData\Local\Temp\ipykernel_16368\1774786928.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            PercentSalaryHike  DistanceFromHome
# Attrition
# 0.0                15.231144          8.915653
# 1.0                15.097046         10.632911

# %%
hr.groupby('MonthlyIncome')['Attrition'].count().plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.scatterplot(data=hr11,x='MonthlyIncome',y='PercentSalaryHike',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='PercentSalaryHike'>

# %%
hr[hr['Gender']=='Male'].groupby('Attrition')['MaritalStatus'].value_counts().plot(kind='bar',title='Male')
# Out:
# <AxesSubplot:title={'center':'Male'}, xlabel='Attrition,MaritalStatus'>

# %%
hr[hr['Gender']=='Female'].groupby('Attrition')['MaritalStatus'].value_counts().plot(kind='bar',title='Female')
# Out:
# <AxesSubplot:title={'center':'Female'}, xlabel='Attrition,MaritalStatus'>

# %%
hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
hr.groupby('Attrition')['PercentSalaryHike'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Attrition,PercentSalaryHike'>
